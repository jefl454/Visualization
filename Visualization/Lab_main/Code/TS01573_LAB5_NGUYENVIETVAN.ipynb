# %%
import pandas as pd
import plotly.express as px
import random

# %% [markdown]
# # Bai 1

# %%
data = {
    "Genre": [
        "Action","Action","Action",
        "Action","Action","Action",

        "RPG","RPG","RPG",
        "RPG","RPG","RPG",

        "Strategy","Strategy","Strategy",
        "Strategy","Strategy","Strategy",

        "Sports","Sports","Sports",
        "Sports","Sports","Sports"
    ],

    "Platform": [
        "PC","PC","Console",
        "Console","Mobile","Mobile",

        "PC","PC","Console",
        "Console","Mobile","Mobile",

        "PC","PC","Console",
        "Console","Mobile","Mobile",

        "PC","PC","Console",
        "Console","Mobile","Mobile"
    ],

    "Game": [
        "Valorant","CS2","Call of Duty",
        "Fortnite","PUBG Mobile","Free Fire",

        "Baldur's Gate 3","Diablo IV","Elden Ring",
        "Final Fantasy XVI","Genshin Impact","Honkai Star Rail",

        "StarCraft II","Age of Empires IV","Civilization VI",
        "Total War","Clash Royale","Rise of Kingdoms",

        "EA FC 25","Football Manager","NBA 2K25",
        "MLB The Show","Dream League Soccer","eFootball"
    ],

    "Revenue": [
        1200,1000,950,
        1300,1600,1400,

        1100,900,1250,
        850,1800,1500,

        700,650,800,
        750,900,950,

        850,700,900,
        650,1200,1000
    ]
}

df = pd.DataFrame(data)

fig = px.treemap(
    df,
    path=["Genre", "Platform", "Game"],
    values="Revenue",
    color="Revenue",
    color_continuous_scale="Viridis",
    title="Global Video Game Revenue Distribution"
)

fig.update_traces(
    textinfo="label+value+percent parent"
)

fig.update_layout(
    margin=dict(t=50, l=25, r=25, b=25)
)

fig.show()

# %% [markdown]
# # Bai 2

# %%
data2 = {
    "Region": ["Asia", "Asia", "Asia", "Europe", "Europe", "Europe"],
    "Country": ["Vietnam", "Thailand", "Japan", "Germany", "France", "Italy"],
    "Value": [120, 100, 200, 150, 130, 90],
}
df2 = pd.DataFrame(data2)
fig = px.sunburst(
    df2, path=["Region", "Country"], values="Value", title="Regional Distribution"
)
fig.show()

# %%
regions = [
    "North", "South", "East", "West", "Central"
]

countries = [
    "Alpha", "Beta", "Gamma", "Delta", "Epsilon",
    "Zeta", "Eta", "Theta", "Iota", "Kappa",
    "Lambda", "Mu", "Nu", "Xi", "Omicron",
    "Pi", "Rho", "Sigma", "Tau", "Upsilon"
]

data = []

for _ in range(100):
    data.append({
        "Region": random.choice(regions),
        "Country": random.choice(countries),
        "Value": random.randint(50, 1000)
    })

df = pd.DataFrame(data)

fig = px.sunburst(
    df,
    path=["Region", "Country"],
    values="Value",
    color="Value",
    color_continuous_scale="Turbo",
    title="Random Regional Distribution"
)

fig.show()

# %% [markdown]
# # Bài 2 mở rộng

# %%
regions = ["North", "South", "East", "West"]

countries = [
    "Alpha", "Beta", "Gamma", "Delta",
    "Epsilon", "Zeta", "Eta", "Theta"
]

cities = [
    "City A", "City B", "City C", "City D",
    "City E", "City F", "City G", "City H",
    "City I", "City J"
]

data = []

for _ in range(200):
    data.append({
        "Region": random.choice(regions),
        "Country": random.choice(countries),
        "City": random.choice(cities),
        "Value": random.randint(100, 5000)
    })

df = pd.DataFrame(data)

fig = px.sunburst(
    df,
    path=["Region", "Country", "City"],
    values="Value",
    color="Value",
    color_continuous_scale="Rainbow",
    title="Random Hierarchical Dataset"
)

fig.update_layout(
    margin=dict(t=50, l=10, r=10, b=10)
)

fig.show()

# %% [markdown]
# # Bài 3
#
# # Chưa có tên loài
#
# # Chưa giải thích các thuộc tính

# %%
from sklearn.datasets import load_iris 
iris = load_iris() 
df3 = pd.DataFrame( 
iris.data, 
columns=iris.feature_names 
) 
df3["species"] = iris.target 
fig = px.scatter_3d( 
df3, 
x="sepal length (cm)", 
y="sepal width (cm)", 
z="petal length (cm)", 
color="species" 
) 
fig.show()

# %%
iris = load_iris()

df3 = pd.DataFrame(
    iris.data,
    columns=iris.feature_names
)

df3["species"] = [
    iris.target_names[i]
    for i in iris.target
]

df3 = df3.rename(columns={
    "sepal length (cm)": "Sepal Length",
    "sepal width (cm)": "Sepal Width",
    "petal length (cm)": "Petal Length",
    "petal width (cm)": "Petal Width"
})

# Scatter 3D
fig = px.scatter_3d(
    df3,
    x="Sepal Length",
    y="Sepal Width",
    z="Petal Length",

    color="species",
    size="Petal Width",

    hover_data=[
        "Sepal Length",
        "Sepal Width",
        "Petal Length",
        "Petal Width"
    ],

    title="Iris Flower Dataset Visualization"
)

fig.update_traces(
    marker=dict(
        size=8,
        opacity=0.8
    )
)

fig.update_layout(
    width=1000,
    height=700,

    scene=dict(
        xaxis_title="Sepal Length (cm)",
        yaxis_title="Sepal Width (cm)",
        zaxis_title="Petal Length (cm)"
    ),

    legend_title="Species"
)

fig.show()

# %%
from sklearn.datasets import fetch_california_housing

# %%
from sklearn.datasets import fetch_california_housing

housing = fetch_california_housing(as_frame=True)
housing_df = housing.frame

fig = px.scatter_3d(
    housing_df,
    x="Longitude",
    y="Latitude",
    z="MedHouseVal",
    color="MedHouseVal",
)
fig.show()
